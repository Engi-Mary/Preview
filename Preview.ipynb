# %% [markdown]
# # Sample 5G System Traces Dataset

# %%
from PIL import Image
# %matplotlib notebook

# %%
im1 = Image.open("SNR.png")
display(im1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im2 = Image.open("CellId-Imsi.png")
display(im2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x576>

# %%
im3 = Image.open("UE-Reg.png")
display(im3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im4 = Image.open("CellId-RB.png")
display(im4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im5 = Image.open("Transmitter-Receiver-Bytes.png")
display(im5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im6 = Image.open("FlowId-Throughput.png")
display(im6)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im7 = Image.open("FlowId-MeanDelay.png")
display(im7)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im8 = Image.open("FlowId-MeanJitter.png")
display(im8)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>

# %%
im9 = Image.open("TxRx-Packets.png")
display(im9)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x504>
