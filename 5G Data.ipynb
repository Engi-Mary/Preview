# %% [markdown]
# # Sample 5G System Traces Dataset

# %%
from PIL import Image
# %matplotlib notebook

# %%
im1 = Image.open("time-snr.png")
display(im1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x450 at 0x7F1BDC5F9D00>

# %%
im2 = Image.open("cellid-frame.png")
display(im2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x450 at 0x7F1B321D0160>

# %%
im3 = Image.open("cellid-mcs.png")
display(im3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x450 at 0x7F1B32272640>

# %%
im4 = Image.open("cellid-tbs.png")
display(im4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x450 at 0x7F1B321D0250>

# %%
im5 = Image.open("cellid-tbler.png")
display(im5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x450 at 0x7F1B32237EB0>
